# %%
## import libraries 
import pandas as pd

# %%
## import summer data 
oly_s = pd.read_csv("data/summer.csv")
oly_s.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
## import winter data 
oly_w = pd.read_csv("data/winter.csv")
oly_w.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
## SUMMER
## what exactly do we have: columns, datatypes, etc. 
oly_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
## WINTER
## what exactly do we have: columns, datatypes, etc. 
oly_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5770 non-null   int64
#  1   City        5770 non-null   object
#  2   Sport       5770 non-null   object
#  3   Discipline  5770 non-null   object
#  4   Athlete     5770 non-null   object
#  5   Country     5770 non-null   object
#  6   Gender      5770 non-null   object
#  7   Event       5770 non-null   object
#  8   Medal       5770 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 405.8+ KB

# %%
## METHODA 1 to return a series 
## df.column_name also returns the Pandas Series 
oly_w.Year
# Out:
# 0       1924
# 1       1924
# 2       1924
# 3       1924
# 4       1924
#         ...
# 5765    2014
# 5766    2014
# 5767    2014
# 5768    2014
# 5769    2014
# Name: Year, Length: 5770, dtype: int64

# %%
## METHOD 2 to return a series (preferred)
## df['columnName'] also returns the Pandas Series 
oly_w["Year"]
# Out:
# 0       1924
# 1       1924
# 2       1924
# 3       1924
# 4       1924
#         ...
# 5765    2014
# 5766    2014
# 5767    2014
# 5768    2014
# 5769    2014
# Name: Year, Length: 5770, dtype: int64

# %%
## dr[["Column1", "Column2"]] returns a dataframe 
df = oly_w[["Year", "City"]]
df.sample(10)
# Out:
#       Year               City
# 5052  2010          Vancouver
# 2514  1992        Albertville
# 3832  2002     Salt Lake City
# 4008  2002     Salt Lake City
# 2521  1992        Albertville
# 2519  1992        Albertville
# 4538  2006              Turin
# 448   1948          St.Moritz
# 804   1956  Cortina d'Ampezzo
# 5473  2014              Sochi

# %%
df = oly_w[["Year", "City"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    5770 non-null   int64
#  1   City    5770 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 90.3+ KB

# %%
## sort by city and year by descending 
city_yr_sort = df.sort_values(by=["City", "Year"], ascending=True)
city_yr_sort
# Out:
#       Year         City
# 2502  1992  Albertville
# 2503  1992  Albertville
# 2504  1992  Albertville
# 2505  1992  Albertville
# 2506  1992  Albertville
# ...    ...          ...
# 5153  2010    Vancouver
# 5154  2010    Vancouver
# 5155  2010    Vancouver
# 5156  2010    Vancouver
# 5157  2010    Vancouver
#
# [5770 rows x 2 columns]

# %%
## sort by city and year but descending 
city_yr_sort = df.sort_values(by=["City", "Year"], ascending=False)
city_yr_sort
# Out:
#       Year         City
# 4629  2010    Vancouver
# 4630  2010    Vancouver
# 4631  2010    Vancouver
# 4632  2010    Vancouver
# 4633  2010    Vancouver
# ...    ...          ...
# 2822  1992  Albertville
# 2823  1992  Albertville
# 2824  1992  Albertville
# 2825  1992  Albertville
# 2826  1992  Albertville
#
# [5770 rows x 2 columns]

# %%
## in oly_s, add "Season" column with the value "Summer"
oly_s["Season"] = "Summer"
oly_s
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal  Season
# 0        Gold  Summer
# 1      Silver  Summer
# 2      Bronze  Summer
# 3        Gold  Summer
# 4      Silver  Summer
# ...       ...     ...
# 31160  Bronze  Summer
# 31161    Gold  Summer
# 31162  Silver  Summer
# 31163  Bronze  Summer
# 31164  Bronze  Summer
#
# [31165 rows x 10 columns]

# %%
oly_w["Season"] = "Winter"
oly_w
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal  Season
# 0       Men  Military Patrol  Bronze  Winter
# 1       Men  Military Patrol  Bronze  Winter
# 2       Men  Military Patrol  Bronze  Winter
# 3       Men  Military Patrol  Bronze  Winter
# 4       Men  Military Patrol    Gold  Winter
# ...     ...              ...     ...     ...
# 5765  Women       Slopestyle  Bronze  Winter
# 5766  Women       Slopestyle    Gold  Winter
# 5767  Women  Snowboard Cross  Silver  Winter
# 5768  Women  Snowboard Cross    Gold  Winter
# 5769  Women  Snowboard Cross  Bronze  Winter
#
# [5770 rows x 10 columns]

# %%
## are the two column headers identical
list(oly_w.columns) == list(oly_s.columns)
# Out:
# True

# %%
## join winter and summer dataframes together into a dataframe called oly 
join_list = [oly_s, oly_w]
oly = pd.concat(join_list, sort = True)
oly
# Out:
#                  Athlete    City Country Discipline  \
# 0          HAJOS, Alfred  Athens     HUN   Swimming
# 1       HERSCHMANN, Otto  Athens     AUT   Swimming
# 2      DRIVAS, Dimitrios  Athens     GRE   Swimming
# 3     MALOKINIS, Ioannis  Athens     GRE   Swimming
# 4     CHASAPIS, Spiridon  Athens     GRE   Swimming
# ...                  ...     ...     ...        ...
# 5765        JONES, Jenny   Sochi     GBR  Snowboard
# 5766     ANDERSON, Jamie   Sochi     USA  Snowboard
# 5767  MALTAIS, Dominique   Sochi     CAN  Snowboard
# 5768        SAMKOVA, Eva   Sochi     CZE  Snowboard
# 5769    TRESPEUCH, Chloe   Sochi     FRA  Snowboard
#
#                            Event Gender   Medal  Season     Sport  Year
# 0                 100M Freestyle    Men    Gold  Summer  Aquatics  1896
# 1                 100M Freestyle    Men  Silver  Summer  Aquatics  1896
# 2     100M Freestyle For Sailors    Men  Bronze  Summer  Aquatics  1896
# 3     100M Freestyle For Sailors    Men    Gold  Summer  Aquatics  1896
# 4     100M Freestyle For Sailors    Men  Silver  Summer  Aquatics  1896
# ...                          ...    ...     ...     ...       ...   ...
# 5765                  Slopestyle  Women  Bronze  Winter    Skiing  2014
# 5766                  Slopestyle  Women    Gold  Winter    Skiing  2014
# 5767             Snowboard Cross  Women  Silver  Winter    Skiing  2014
# 5768             Snowboard Cross  Women    Gold  Winter    Skiing  2014
# 5769             Snowboard Cross  Women  Bronze  Winter    Skiing  2014
#
# [36935 rows x 10 columns]

# %%
## confirm that you have the correct number of rows after th join.
## you can scroll up to cunt the number of entreies in oly_w and oly_s.
## The totals should be equal to the value generated below 

oly.shape[0] == oly_w.shape[0] + oly_s.shape[0]
# Out:
# True

# %%
oly_w.shape[0]
# Out:
# 5770

# %%
##  generate random sample of 20 rows 

oly.sample(20)
# Out:
#                         Athlete                   City Country     Discipline  \
# 15252             VERMES, Alban                 Moscow     HUN       Swimming
# 9727      ANDERSON, Paul Edward  Melbourne / Stockholm     USA  Weightlifting
# 1596           KRUGLOV, Nikolay              Innsbruck     URS       Biathlon
# 30903   YAGUE ENRIQUE, Brigitte                 London     ESP      Taekwondo
# 27235         TRICKETT, Lisbeth                Beijing     AUS       Swimming
# 953           HINTERSEER, Ernst           Squaw Valley     AUT  Alpine Skiing
# 24166        VEZZALI, Valentina                 Sydney     ITA        Fencing
# 28368                 HE, Kexin                Beijing     CHN    Artistic G.
# 25576              GUEVARA, Ana                 Athens     MEX      Athletics
# 4599         MARTINO, Francesco                  Paris     ITA    Artistic G.
# 1240           SHEPPARD, Melvin                 London     USA      Athletics
# 1585   PENNELL, Vane Hungerford                 London     GBR        Rackets
# 25505        MYLONAKI, Anthoula                 Athens     GRE     Water polo
# 14492            BEHR, Matthias               Montreal     FRG        Fencing
# 25303              HENRY, Jodie                 Athens     AUS       Swimming
# 476      GOSSLER, Gustav Ludwig                  Paris     GER         Rowing
# 21379            NAMESNIK, Eric                Atlanta     USA       Swimming
# 22549               ARNAU, Xavi                Atlanta     ESP         Hockey
# 15032     BASSHAM, Lance Robert               Montreal     USA       Shooting
# 16776       MCDONALD, Andrew J.            Los Angeles     USA     Water polo
#
#                                      Event Gender   Medal  Season  \
# 15252                    200M Breaststroke    Men  Silver  Summer
# 9727           + 90KG, Total (Heavyweight)    Men    Gold  Summer
# 1596                         4X7.5KM Relay    Men    Gold  Winter
# 30903                              - 49 KG  Women  Silver  Summer
# 27235                       100M Freestyle  Women  Silver  Summer
# 953                           Giant Slalom    Men  Bronze  Winter
# 24166                            Foil Team  Women    Gold  Summer
# 28368                          Uneven Bars  Women    Gold  Summer
# 25576                                 400M  Women  Silver  Summer
# 4599                                 Rings    Men    Gold  Summer
# 1240                                  800M    Men    Gold  Summer
# 1585                                Double    Men    Gold  Summer
# 25505                           Water Polo  Women  Silver  Summer
# 14492                            Foil Team    Men    Gold  Summer
# 25303               4X100M Freestyle Relay  Women    Gold  Summer
# 476    Four-Oared Shell With Coxswain (4-)    Men    Gold  Summer
# 21379               400M Individual Medley    Men  Silver  Summer
# 22549                               Hockey    Men  Silver  Summer
# 15032   50M Rifle 3 Positions (3X40 Shots)    Men    Gold  Summer
# 16776                           Water Polo    Men  Silver  Summer
#
#                Sport  Year
# 15252       Aquatics  1980
# 9727   Weightlifting  1956
# 1596        Biathlon  1976
# 30903      Taekwondo  2012
# 27235       Aquatics  2008
# 953           Skiing  1960
# 24166        Fencing  2000
# 28368     Gymnastics  2008
# 25576      Athletics  2004
# 4599      Gymnastics  1924
# 1240       Athletics  1908
# 1585         Rackets  1908
# 25505       Aquatics  2004
# 14492        Fencing  1976
# 25303       Aquatics  2004
# 476           Rowing  1900
# 21379       Aquatics  1996
# 22549         Hockey  1996
# 15032       Shooting  1976
# 16776       Aquatics  1984

# %%
oly.to_csv("data/olympics.csv", encoding = "UTF-8", index= False)

# %%
## Sochi subset 
## df[df["column_name"] == "value_in_column"]
df_sochi = oly[oly["City"] == "Sochi"]
df_sochi
# Out:
#                       Athlete   City Country Discipline            Event  \
# 5158    LANDERTINGER, Dominik  Sochi     AUT   Biathlon             10KM
# 5159         SOUKUP, Jaroslav  Sochi     CZE   Biathlon             10KM
# 5160   BJOERNDALEN, Ole Einar  Sochi     NOR   Biathlon             10KM
# 5161          MORAVEC, Ondrej  Sochi     CZE   Biathlon   12.5Km Pursuit
# 5162  BEATRIX, Jean Guillaume  Sochi     FRA   Biathlon   12.5Km Pursuit
# ...                       ...    ...     ...        ...              ...
# 5765             JONES, Jenny  Sochi     GBR  Snowboard       Slopestyle
# 5766          ANDERSON, Jamie  Sochi     USA  Snowboard       Slopestyle
# 5767       MALTAIS, Dominique  Sochi     CAN  Snowboard  Snowboard Cross
# 5768             SAMKOVA, Eva  Sochi     CZE  Snowboard  Snowboard Cross
# 5769         TRESPEUCH, Chloe  Sochi     FRA  Snowboard  Snowboard Cross
#
#      Gender   Medal  Season     Sport  Year
# 5158    Men  Silver  Winter  Biathlon  2014
# 5159    Men  Bronze  Winter  Biathlon  2014
# 5160    Men    Gold  Winter  Biathlon  2014
# 5161    Men  Silver  Winter  Biathlon  2014
# 5162    Men  Bronze  Winter  Biathlon  2014
# ...     ...     ...     ...       ...   ...
# 5765  Women  Bronze  Winter    Skiing  2014
# 5766  Women    Gold  Winter    Skiing  2014
# 5767  Women  Silver  Winter    Skiing  2014
# 5768  Women    Gold  Winter    Skiing  2014
# 5769  Women  Bronze  Winter    Skiing  2014
#
# [612 rows x 10 columns]

# %%
## store subset into dataframe called sochi_df 
df_sochi = oly[oly["City"] == "Sochi"].sample(20)
df_sochi
# Out:
#                  Athlete   City Country                 Discipline  \
# 5226   FOGT, Christopher  Sochi     USA                  Bobsleigh
# 5254       BREWSTER, Tom  Sochi     GBR                    Curling
# 5701       FRENZEL, Eric  Sochi     GER            Nordic Combined
# 5749      MCMORRIS, Mark  Sochi     CAN                  Snowboard
# 5529     BERGSMA, Jorrit  Sochi     NED              Speed skating
# 5227     HOLCOMB, Steven  Sochi     USA                  Bobsleigh
# 5614    DUVILLARD, Robin  Sochi     FRA       Cross Country Skiing
# 5460        BROWN, Jason  Sochi     USA             Figure skating
# 5449       CHAN, Patrick  Sochi     CAN             Figure skating
# 5229  TOMASEVICZ, Curtis  Sochi     USA                  Bobsleigh
# 5517    FONTANA, Arianna  Sochi     ITA  Short Track Speed Skating
# 5664       FABJAN, Vesna  Sochi     SLO       Cross Country Skiing
# 5671       MORRIS, David  Sochi     AUS           Freestyle Skiing
# 5350    STEEN, Alexander  Sochi     SWE                 Ice Hockey
# 5367   ROUGEAU, Lauriane  Sochi     CAN                 Ice Hockey
# 5404      KNIGHT, Hilary  Sochi     USA                 Ice Hockey
# 5364  MIKKELSON, Meaghan  Sochi     CAN                 Ice Hockey
# 5353      AGOSTA, Meghan  Sochi     CAN                 Ice Hockey
# 5644     BJOERGEN, Marit  Sochi     NOR       Cross Country Skiing
# 5684   GOEPPER, Nicholas  Sochi     USA           Freestyle Skiing
#
#                Event Gender   Medal  Season       Sport  Year
# 5226        Four-Man    Men  Bronze  Winter   Bobsleigh  2014
# 5254         Curling    Men  Silver  Winter     Curling  2014
# 5701  Ind. K90 (70M)    Men    Gold  Winter      Skiing  2014
# 5749      Slopestyle    Men  Bronze  Winter      Skiing  2014
# 5529          10000M    Men    Gold  Winter     Skating  2014
# 5227        Four-Man    Men  Bronze  Winter   Bobsleigh  2014
# 5614    4X10KM Relay    Men  Bronze  Winter      Skiing  2014
# 5460            Team    Men  Bronze  Winter     Skating  2014
# 5449            Team    Men  Silver  Winter     Skating  2014
# 5229        Four-Man    Men  Bronze  Winter   Bobsleigh  2014
# 5517     3000M Relay  Women  Bronze  Winter     Skating  2014
# 5664    Sprint 1.5KM  Women  Bronze  Winter      Skiing  2014
# 5671         Aerials    Men  Silver  Winter      Skiing  2014
# 5350      Ice Hockey    Men  Silver  Winter  Ice Hockey  2014
# 5367      Ice Hockey  Women    Gold  Winter  Ice Hockey  2014
# 5404      Ice Hockey  Women  Silver  Winter  Ice Hockey  2014
# 5364      Ice Hockey  Women    Gold  Winter  Ice Hockey  2014
# 5353      Ice Hockey  Women    Gold  Winter  Ice Hockey  2014
# 5644            30KM  Women    Gold  Winter      Skiing  2014
# 5684  Ski Slopestyle    Men  Bronze  Winter      Skiing  2014

# %%
## How many men and women won medals Sochi?
## df_name["column_name"].value_counts()

df_sochi["Gender"].value_counts()
# Out:
# Men      13
# Women     7
# Name: Gender, dtype: int64

# %%
## count medals in all olympics - how many gold, silver, and bronze were given out?
oly["Medal"].value_counts()
# Out:
# Gold      12407
# Bronze    12288
# Silver    12240
# Name: Medal, dtype: int64
